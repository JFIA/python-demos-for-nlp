# %%
import pandas as pd

from IPython.display import display

import matplotlib.pyplot as plt

data_train= pd.read_csv('ch/input/train.csv')

data.head() #默认输出前五行



na_count = data_train.isnull().sum().sort_values(ascending=False)   #返回的是Series类型

na_rate = na_count / len(data_train)

na_data = pd.concat([na_count,na_rate],axis=1,keys=['count','ratio'])

data_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# 11      12          60       RL         85.0    11924   Pave   NaN      IR1
# 12      13          20       RL          NaN    12968   Pave   NaN      IR2
# 13      14          20       RL         91.0    10652   Pave   NaN      IR1
# 14      15          20       RL          NaN    10920   Pave   NaN      IR1
# 15      16          45       RM         51.0     6120   Pave   NaN      Reg
# 16      17          20       RL          NaN    11241   Pave   NaN      IR1
# 17      18          90       RL         72.0    10791   Pave   NaN      Reg
# 18      19          20       RL         66.0    13695   Pave   NaN      Reg
# 19      20          20       RL         70.0     7560   Pave   NaN      Reg
# 20      21          60       RL        101.0    14215   Pave   NaN      IR1
# 21      22          45       RM         57.0     7449   Pave  Grvl      Reg
# 22      23          20       RL         75.0     9742   Pave   NaN      Reg
# 23      24         120       RM         44.0     4224   Pave   NaN      Reg
# 24      25          20       RL          NaN     8246   Pave   NaN      IR1
# 25      26          20       RL        110.0    14230   Pave   NaN      Reg
# 26      27          20       RL         60.0     7200   Pave   NaN      Reg
# 27      28          20       RL         98.0    11478   Pave   NaN      Reg
# 28      29          20       RL         47.0    16321   Pave   NaN      IR1
# 29      30          30       RM         60.0     6324   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1430  1431          60       RL         60.0    21930   Pave   NaN      IR3
# 1431  1432         120       RL          NaN     4928   Pave   NaN      IR1
# 1432  1433          30       RL         60.0    10800   Pave  Grvl      Reg
# 1433  1434          60       RL         93.0    10261   Pave   NaN      IR1
# 1434  1435          20       RL         80.0    17400   Pave   NaN      Reg
# 1435  1436          20       RL         80.0     8400   Pave   NaN      Reg
# 1436  1437          20       RL         60.0     9000   Pave   NaN      Reg
# 1437  1438          20       RL         96.0    12444   Pave   NaN      Reg
# 1438  1439          20       RM         90.0     7407   Pave   NaN      Reg
# 1439  1440          60       RL         80.0    11584   Pave   NaN      Reg
# 1440  1441          70       RL         79.0    11526   Pave   NaN      IR1
# 1441  1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1442  1443          60       FV         85.0    11003   Pave   NaN      Reg
# 1443  1444          30       RL          NaN     8854   Pave   NaN      Reg
# 1444  1445          20       RL         63.0     8500   Pave   NaN      Reg
# 1445  1446          85       RL         70.0     8400   Pave   NaN      Reg
# 1446  1447          20       RL          NaN    26142   Pave   NaN      IR1
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1448  1449          50       RL         70.0    11767   Pave   NaN      Reg
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature  \
# 0            Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1            Lvl    AllPub    ...            0    NaN    NaN         NaN
# 2            Lvl    AllPub    ...            0    NaN    NaN         NaN
# 3            Lvl    AllPub    ...            0    NaN    NaN         NaN
# 4            Lvl    AllPub    ...            0    NaN    NaN         NaN
# 5            Lvl    AllPub    ...            0    NaN  MnPrv        Shed
# 6            Lvl    AllPub    ...            0    NaN    NaN         NaN
# 7            Lvl    AllPub    ...            0    NaN    NaN        Shed
# 8            Lvl    AllPub    ...            0    NaN    NaN         NaN
# 9            Lvl    AllPub    ...            0    NaN    NaN         NaN
# 10           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 11           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 12           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 13           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 14           Lvl    AllPub    ...            0    NaN   GdWo         NaN
# 15           Lvl    AllPub    ...            0    NaN  GdPrv         NaN
# 16           Lvl    AllPub    ...            0    NaN    NaN        Shed
# 17           Lvl    AllPub    ...            0    NaN    NaN        Shed
# 18           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 19           Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 20           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 21           Bnk    AllPub    ...            0    NaN  GdPrv         NaN
# 22           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 23           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 24           Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 25           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 26           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 27           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 28           Lvl    AllPub    ...            0    NaN    NaN         NaN
# 29           Lvl    AllPub    ...            0    NaN    NaN         NaN
# ...          ...       ...    ...          ...    ...    ...         ...
# 1430         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1431         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1432         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1433         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1434         Low    AllPub    ...            0    NaN    NaN         NaN
# 1435         Lvl    AllPub    ...            0    NaN  GdPrv         NaN
# 1436         Lvl    AllPub    ...            0    NaN   GdWo         NaN
# 1437         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1438         Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 1439         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1440         Bnk    AllPub    ...            0    NaN    NaN         NaN
# 1441         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1442         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1443         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1444         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1445         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1446         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1447         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1448         Lvl    AllPub    ...            0    NaN   GdWo         NaN
# 1449         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1450         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1451         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1452         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1453         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1454         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1455         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1456         Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 1457         Lvl    AllPub    ...            0    NaN  GdPrv        Shed
# 1458         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1459         Lvl    AllPub    ...            0    NaN    NaN         NaN
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0          0      2   2008        WD         Normal     208500
# 1          0      5   2007        WD         Normal     181500
# 2          0      9   2008        WD         Normal     223500
# 3          0      2   2006        WD        Abnorml     140000
# 4          0     12   2008        WD         Normal     250000
# 5        700     10   2009        WD         Normal     143000
# 6          0      8   2007        WD         Normal     307000
# 7        350     11   2009        WD         Normal     200000
# 8          0      4   2008        WD        Abnorml     129900
# 9          0      1   2008        WD         Normal     118000
# 10         0      2   2008        WD         Normal     129500
# 11         0      7   2006       New        Partial     345000
# 12         0      9   2008        WD         Normal     144000
# 13         0      8   2007       New        Partial     279500
# 14         0      5   2008        WD         Normal     157000
# 15         0      7   2007        WD         Normal     132000
# 16       700      3   2010        WD         Normal     149000
# 17       500     10   2006        WD         Normal      90000
# 18         0      6   2008        WD         Normal     159000
# 19         0      5   2009       COD        Abnorml     139000
# 20         0     11   2006       New        Partial     325300
# 21         0      6   2007        WD         Normal     139400
# 22         0      9   2008        WD         Normal     230000
# 23         0      6   2007        WD         Normal     129900
# 24         0      5   2010        WD         Normal     154000
# 25         0      7   2009        WD         Normal     256300
# 26         0      5   2010        WD         Normal     134800
# 27         0      5   2010        WD         Normal     306000
# 28         0     12   2006        WD         Normal     207500
# 29         0      5   2008        WD         Normal      68500
# ...      ...    ...    ...       ...            ...        ...
# 1430       0      7   2006        WD         Normal     192140
# 1431       0     10   2009        WD         Normal     143750
# 1432       0      8   2007        WD         Normal      64500
# 1433       0      5   2008        WD         Normal     186500
# 1434       0      5   2006        WD         Normal     160000
# 1435       0      7   2008       COD        Abnorml     174000
# 1436       0      5   2007        WD         Normal     120500
# 1437       0     11   2008       New        Partial     394617
# 1438       0      4   2010        WD         Normal     149700
# 1439       0     11   2007        WD         Normal     197000
# 1440       0      9   2008        WD         Normal     191000
# 1441       0      5   2008        WD         Normal     149300
# 1442       0      4   2009        WD         Normal     310000
# 1443       0      5   2009        WD         Normal     121000
# 1444       0     11   2007        WD         Normal     179600
# 1445       0      5   2007        WD         Normal     129000
# 1446       0      4   2010        WD         Normal     157900
# 1447       0     12   2007        WD         Normal     240000
# 1448       0      5   2007        WD         Normal     112000
# 1449       0      8   2006        WD        Abnorml      92000
# 1450       0      9   2009        WD         Normal     136000
# 1451       0      5   2009       New        Partial     287090
# 1452       0      5   2006        WD         Normal     145000
# 1453       0      7   2006        WD        Abnorml      84500
# 1454       0     10   2009        WD         Normal     185000
# 1455       0      8   2007        WD         Normal     175000
# 1456       0      2   2010        WD         Normal     210000
# 1457    2500      5   2010        WD         Normal     266500
# 1458       0      4   2010        WD         Normal     142125
# 1459       0      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
import re

import xlwt

fr = open('C:\\Users\\Tommy\\Desktop\\日志文档\\action06.txt', encoding= 'UTF-8')

text = fr.reammaad()

text = re.split(r'[\n ,]',text)

words = [w.replace('\\' ,'') for w in text]

words2 = [re.sub('"','',w) for w in words]

wbk = xlwt.Workbook()

sheet = wbk.add_sheet('sheet1')

for i in range(len(words2)):
    
    sheet.write(i,1 ,words2[i])
    
wbk.save('pcs.xls')
words2
# Out:
# ['x',
#  '1',
#  '{_index:action-2018.06',
#  '_type:action',
#  '_id:788f33268c6497488309946d295824e8b7c0144c',
#  '_score:1',
#  '_source:{occurredAt:1529610530000',
#  'applicationType:SSL',
#  'targetObject:{port:44292',
#  'ip:192.168.1.31}',
#  'original:{index:event20180622_1',
#  'id:16549073',
#  'type:/acc/normal}',
#  'level:一般',
#  'dataStatus:RealTime',
#  'sourceObject:{port:443',
#  'ip:192.168.140.174}',
#  'abstract:服务控制或应用控制',
#  'bytesSent:0',
#  'type:/acc',
#  'receivedAt:1529610407027',
#  'message:localhost',
#  'fwlog:',
#  '日志类型:服务控制或应用控制',
#  '',
#  '用户:(null)',
#  '',
#  '源IP:192.168.140.174',
#  '',
#  '源端口:443',
#  '',
#  '目的IP:192.168.1.31',
#  '',
#  '目的端口:44292',
#  '',
#  '应用类型:SSL',
#  '',
#  '应用名称:any',
#  '',
#  '系统动作:被记录',
#  'messageSha256:13ccfe2f4bebd75f738f7ef2b480aecc05fef41864773c59baedd451e9b33216',
#  'bytesReceived:0',
#  'subtype:/acc/normal',
#  'response:发现',
#  'name:服务控制或应用控制',
#  'protocols:{network:hopopt}',
#  'dataSource:log',
#  'device:{product:深信服下一代防火墙',
#  'vendor:SANGFOR-深信服',
#  'ip:10.1.1.5',
#  'name:深信服防火墙',
#  'type:/security/FW}',
#  'username:(null)}}',
#  '2',
#  '{_index:action-2018.06',
#  '_type:action',
#  '_id:d4a7ae4f13e83f250bdb6b61f43ab2a6884fa3c8',
#  '_score:1',
#  '_source:{occurredAt:1529610532000',
#  'applicationType:Other',
#  'targetObject:{port:53',
#  'ip:61.129.8.159}',
#  'original:{index:event20180622_1',
#  'id:16549085',
#  'type:/acc/other}',
#  'level:一般',
#  'dataStatus:RealTime',
#  'sourceObject:{port:46411',
#  'ip:192.168.1.4}',
#  'abstract:服务控制或应用控制',
#  'bytesSent:0',
#  'type:/acc',
#  'receivedAt:1529610409028',
#  'message:localhost',
#  'fwlog:',
#  '日志类型:服务控制或应用控制',
#  '',
#  '用户:(null)',
#  '',
#  '源IP:192.168.1.4',
#  '',
#  '源端口:46411',
#  '',
#  '目的IP:61.129.8.159',
#  '',
#  '目的端口:53',
#  '',
#  '应用类型:Other',
#  '',
#  '应用名称:any',
#  '',
#  '系统动作:被记录',
#  'messageSha256:62356d1150f921d9ada74a87137ee746c9653052b826f4605587303b142a230e',
#  'bytesReceived:0',
#  'subtype:/acc/other',
#  'response:发现',
#  'name:服务控制或应用控制',
#  'protocols:{network:hopopt}',
#  'dataSource:log',
#  'device:{product:深信服下一代防火墙',
#  'vendor:SANGFOR-深信服',
#  'ip:10.1.1.5',
#  'name:深信服防火墙',
#  'type:/security/FW}',
#  'username:(null)}}',
#  '3',
#  '{_index:action-2018.06',
#  '_type:action',
#  '_id:aa4a603c5f88e2f55740895b4f341507da5d3746',
#  '_score:1',
#  '_source:{occurredAt:1529610530000',
#  'applicationType:Other',
#  'targetObject:{port:6002',
#  'ip:111.1.6.195}',
#  'original:{index:event20180622_2',
#  'id:16549075',
#  'type:/acc/other}',
#  'level:一般',
#  'dataStatus:RealTime',
#  'sourceObject:{port:46662',
#  'ip:192.168.1.4}',
#  'abstract:服务控制或应用控制',
#  'bytesSent:0',
#  'type:/acc',
#  'receivedAt:1529610407027',
#  'message:localhost',
#  'fwlog:',
#  '日志类型:服务控制或应用控制',
#  '',
#  '用户:(null)',
#  '',
#  '源IP:192.168.1.4',
#  '',
#  '源端口:46662',
#  '',
#  '目的IP:111.1.6.195',
#  '',
#  '目的端口:6002',
#  '',
#  '应用类型:Other',
#  '',
#  '应用名称:any',
#  '',
#  '系统动作:被记录',
#  'messageSha256:9834c86526de58e6789fe1eafaeca5cf454c44d9ffe943cca1f64f132a763963',
#  'bytesReceived:0',
#  'subtype:/acc/other',
#  'response:发现',
#  'name:服务控制或应用控制',
#  'protocols:{network:hopopt}',
#  'dataSource:log',
#  'device:{product:深信服下一代防火墙',
#  'vendor:SANGFOR-深信服',
#  'ip:10.1.1.5',
#  'name:深信服防火墙',
#  'type:/security/FW}',
#  'username:(null)}}',
#  '4',
#  '{_index:action-2018.06',
#  '_type:action',
#  '_id:692d917bfdb424b817771ac20ddaf93316a9dc2c',
#  '_score:1',
#  '_source:{occurredAt:1529610530000',
#  'applicationType:NTP',
#  'targetObject:{port:0}',
#  'original:{index:event20180622_3',
#  'id:16549077',
#  'type:/datatrans/traffic}',
#  'level:一般',
#  'dataStatus:RealTime',
#  'sourceObject:{port:0',
#  'ip:192.168.1.198}',
#  'abstract:NTP',
#  'bytesSent:90',
#  'type:/datatrans',
#  'receivedAt:1529610407508',
#  'message:localhost',
#  'fwlog:',
#  '日志类型:流量审计',
#  '',
#  '应用类型:NTP',
#  '',
#  '用户名/主机:192.168.1.198',
#  '',
#  '上行流量(KB):90',
#  '',
#  '下行流量(KB):90',
#  '',
#  '总流量(KB):180',
#  'messageSha256:4fde840f43b9c1f2ac628b2fcf35c43e9cf37bba2ca175f5081bf534c576b97f',
#  'bytesReceived:90',
#  'subtype:/datatrans/traffic',
#  'response:允许',
#  'name:流量审计',
#  'protocols:{network:hopopt}',
#  'dataSource:log',
#  'device:{product:深信服下一代防火墙',
#  'vendor:SANGFOR-深信服',
#  'ip:10.1.1.5',
#  'name:深信服防火墙',
#  'type:/security/FW}}}',
#  '5',
#  '{_index:action-2018.06',
#  '_type:action',
#  '_id:309e589bd45de3e71db11d294950ac26a2896984',
#  '_score:1',
#  '_source:{occurredAt:1529610588000',
#  'applicationType:Other',
#  'targetObject:{port:80',
#  'ip:115.239.210.27}',
#  'original:{index:event20180622_2',
#  'id:16549244',
#  'type:/acc/other}',
#  'level:一般',
#  'dataStatus:RealTime',
#  'sourceObject:{port:57748',
#  'ip:192.168.10.234}',
#  'abstract:服务控制或应用控制',
#  'bytesSent:0',
#  'type:/acc',
#  'receivedAt:1529610465048',
#  'message:localhost',
#  'fwlog:',
#  '日志类型:服务控制或应用控制',
#  '',
#  '用户:(null)',
#  '',
#  '源IP:192.168.10.234',
#  '',
#  '源端口:57748',
#  '',
#  '目的IP:115.239.210.27',
#  '',
#  '目的端口:80',
#  '',
#  '应用类型:Other',
#  '',
#  '应用名称:any',
#  '',
#  '系统动作:被记录',
#  'messageSha256:6f9b456b7d7433e2ef203b7873b157a462062a77ec3df266abc45500c0927557',
#  'bytesReceived:0',
#  'subtype:/acc/other',
#  'response:发现',
#  'name:服务控制或应用控制',
#  'protocols:{network:hopopt}',
#  'dataSource:log',
#  'device:{product:深信服下一代防火墙',
#  'vendor:SANGFOR-深信服',
#  'ip:10.1.1.5',
#  'name:深信服防火墙',
#  'type:/security/FW}',
#  'username:(null)}}',
#  '6',
#  '{_index:action-2018.06',
#  '_type:action',
#  '_id:587bd89febcf06938a951e3fb2a9f94e200dae63',
#  '_score:1',
#  '_source:{occurredAt:1529610588000',
#  'applicationType:SSL',
#  'targetObject:{port:443',
#  'ip:115.239.210.27}',
#  'original:{index:event20180622_3',
#  'id:16549243',
#  'type:/acc/normal}',
#  'level:一般',
#  'dataStatus:RealTime',
#  'sourceObject:{port:57749',
#  'ip:192.168.10.234}',
#  'abstract:服务控制或应用控制',
#  'bytesSent:0',
#  'type:/acc',
#  'receivedAt:1529610465048',
#  'message:localhost',
#  'fwlog:',
#  '日志类型:服务控制或应用控制',
#  '',
#  '用户:(null)',
#  '',
#  '源IP:192.168.10.234',
#  '',
#  '源端口:57749',
#  '',
#  '目的IP:115.239.210.27',
#  '',
#  '目的端口:443',
#  '',
#  '应用类型:SSL',
#  '',
#  '应用名称:any',
#  '',
#  '系统动作:被记录',
#  'messageSha256:eb9a2e95723ea69d5b68c548d9cab296271741ecbbd673847e18a3c9070fb557',
#  'bytesReceived:0',
#  'subtype:/acc/normal',
#  'response:发现',
#  'name:服务控制或应用控制',
#  'protocols:{network:hopopt}',
#  'dataSource:log',
#  'device:{product:深信服下一代防火墙',
#  'vendor:SANGFOR-深信服',
#  'ip:10.1.1.5',
#  'name:深信服防火墙',
#  'type:/security/FW}',
#  'username:(null)}}',
#  '7',
#  '{_index:action-2018.06',
#  '_type:action',
#  '_id:a32d0ecd22f2c1e9292ac5de73f9bf9243c7b663',
#  '_score:1',
#  '_source:{occurredAt:1529610588000',
#  'applicationType:Other',
#  'targetObject:{port:22',
#  'ip:60.191.151.144}',
#  'original:{index:event20180622_3',
#  'id:16549245',
#  'type:/acc/other}',
#  'level:一般',
#  'dataStatus:RealTime',
#  'sourceObject:{port:48169',
#  'ip:192.168.1.4}',
#  'abstract:服务控制或应用控制',
#  'bytesSent:0',
#  'type:/acc',
#  'receivedAt:1529610465048',
#  'message:localhost',
#  'fwlog:',
#  '日志类型:服务控制或应用控制',
#  '',
#  '用户:(null)',
#  '',
#  '源IP:192.168.1.4',
#  '',
#  '源端口:48169',
#  '',
#  '目的IP:60.191.151.144',
#  '',
#  '目的端口:22',
#  '',
#  '应用类型:Other',
#  '',
#  '应用名称:any',
#  '',
#  '系统动作:被记录',
#  'messageSha256:ac31f051c5d1f98aefa2efff86187a48545ed386e5c1e9cccbdddbcf9151b3bb',
#  'bytesReceived:0',
#  'subtype:/acc/other',
#  'response:发现',
#  'name:服务控制或应用控制',
#  'protocols:{network:hopopt}',
#  'dataSource:log',
#  'device:{product:深信服下一代防火墙',
#  'vendor:SANGFOR-深信服',
#  'ip:10.1.1.5',
#  'name:深信服防火墙',
#  'type:/security/FW}',
#  'username:(null)}}',
#  '8',
#  '{_index:action-2018.06',
#  '_type:action',
#  '_id:133eda044988e840a7e7bc36f5f9ab2a71f2e6dd',
#  '_score:1',
#  '_source:{occurredAt:1529610570000',
#  'applicationType:Other',
#  'targetObject:{port:443',
#  'ip:192.168.140.174}',
#  'original:{index:event20180622_3',
#  'id:16549196',
#  'type:/acc/other}',
#  'level:一般',
#  'dataStatus:RealTime',
#  'sourceObject:{port:41532',
#  'ip:192.168.1.30}',
#  'abstract:服务控制或应用控制',
#  'bytesSent:0',
#  'type:/acc',
#  'receivedAt:1529610447041',
#  'message:localhost',
#  'fwlog:',
#  '日志类型:服务控制或应用控制',
#  '',
#  '用户:(null)',
#  '',
#  '源IP:192.168.1.30',
#  '',
#  '源端口:41532',
#  '',
#  '目的IP:192.168.140.174',
#  '',
#  '目的端口:443',
#  '',
#  '应用类型:Other',
#  '',
#  '应用名称:any',
#  '',
#  '系统动作:被记录',
#  'messageSha256:8dd61fc36e3cdfa778cd3f836d2c1a5af59705e3eacd8687ae11bd7474adb705',
#  'bytesReceived:0',
#  'subtype:/acc/other',
#  'response:发现',
#  'name:服务控制或应用控制',
#  'protocols:{network:hopopt}',
#  'dataSource:log',
#  'device:{product:深信服下一代防火墙',
#  'vendor:SANGFOR-深信服',
#  'ip:10.1.1.5',
#  'name:深信服防火墙',
#  'type:/security/FW}',
#  'username:(null)}}',
#  '9',
#  '{_index:action-2018.06',
#  '_type:action',
#  '_id:379fc859f9b0b0bbd63247ff9bbb5ec0b0bfb2fa',
#  '_score:1',
#  '_source:{occurredAt:1529610572000',
#  'applicationType:Other',
#  'targetObject:{port:53',
#  'ip:182.140.167.166}',
#  'original:{index:event20180622_5',
#  'id:16549201',
#  'type:/acc/other}',
#  'level:一般',
#  'dataStatus:RealTime',
#  'sourceObject:{port:47393',
#  'ip:192.168.1.4}',
#  'abstract:服务控制或应用控制',
#  'bytesSent:0',
#  'type:/acc',
#  'receivedAt:1529610449043',
#  'message:localhost',
#  'fwlog:',
#  '日志类型:服务控制或应用控制',
#  '',
#  '用户:(null)',
#  '',
#  '源IP:192.168.1.4',
#  '',
#  '源端口:47393',
#  '',
#  '目的IP:182.140.167.166',
#  '',
#  '目的端口:53',
#  '',
#  '应用类型:Other',
#  '',
#  '应用名称:any',
#  '',
#  '系统动作:被记录',
#  'messageSha256:52660f213f4c354eace2b0bee71715a8f4712d5fc7cb2d17473c4021069da2d6',
#  'bytesReceived:0',
#  'subtype:/acc/other',
#  'response:发现',
#  'name:服务控制或应用控制',
#  'protocols:{network:hopopt}',
#  'dataSource:log',
#  'device:{product:深信服下一代防火墙',
#  'vendor:SANGFOR-深信服',
#  'ip:10.1.1.5',
#  'name:深信服防火墙',
#  'type:/security/FW}',
#  'username:(null)}}',
#  '10',
#  '{_index:action-2018.06',
#  '_type:action',
#  '_id:f71e47a68747228a794b053559404e149508ca48',
#  '_score:1',
#  '_source:{occurredAt:1529610536000',
#  'applicationType:Other',
#  'targetObject:{port:4402',
#  'ip:192.168.1.153}',
#  'original:{index:event20180622_0',
#  'id:16549095',
#  'type:/acc/other}',
#  'level:一般',
#  'dataStatus:RealTime',
#  'sourceObject:{port:57797',
#  'ip:192.168.129.128}',
#  'abstract:服务控制或应用控制',
#  'bytesSent:0',
#  'type:/acc',
#  'receivedAt:1529610413029',
#  'message:localhost',
#  'fwlog:',
#  '日志类型:服务控制或应用控制',
#  '',
#  '用户:(null)',
#  '',
#  '源IP:192.168.129.128',
#  '',
#  '源端口:57797',
#  '',
#  '目的IP:192.168.1.153',
#  '',
#  '目的端口:4402',
#  '',
#  '应用类型:Other',
#  '',
#  '应用名称:any',
#  '',
#  '系统动作:被记录',
#  'messageSha256:b8439e6180b4551e3842d09479b10e727702fce8561bd851d297c68dad0abb0e',
#  'bytesReceived:0',
#  'subtype:/acc/other',
#  'response:发现',
#  'name:服务控制或应用控制',
#  'protocols:{network:hopopt}',
#  'dataSource:log',
#  'device:{product:深信服下一代防火墙',
#  'vendor:SANGFOR-深信服',
#  'ip:10.1.1.5',
#  'name:深信服防火墙',
#  'type:/security/FW}',
#  'username:(null)}}',
#  '']

# %%
import networkx as nx

import matplotlib.pyplot as plt

G=nx.Graph()#创建空图
 
#添加节点
G.add_node('a')
G.add_node(1)                  #添加单个节点
G.add_nodes_from([2,3,4])      #添加一些节点，容器，（可以是list, dict, set，）
 
#添加边，如果点不在图中，会自动创建点
G.add_edge(1,'a',weight=1.2)   #添加单条边，连接1，‘a’的边,可以赋予边属性以及他的值
G.add_edges_from([(2,3),(3,4)])#添加一些边（列表）
G.add_weighted_edges_from([(1,'a',0.1),(4,2,0.5)])#给边赋予权重
 
#移除边
G.remove_edge(2,4)             #移除一条边    
G.remove_edges_from([(3,4),])  #移除一些边
G.remove_node(1)               #移除单个节点
G.remove_nodes_from([4,])      #移除一些节点
#绘图
nx.draw(G,                          # 图
        pos=nx.circular_layout(G),  # 图的布局
        alpha=0.5,                  # 图的透明度（默认1.0不透明，0完全透明） 
        with_labels=True,           # 节点是否带标签
        font_size=18,               # 节点标签字体大小
        node_size=400,              # 指定节点的尺寸大小
        node_color='blue',          # 指定节点的颜色
        node_shape='o',             # 节点的形状

        edge_color='r',             # 边的颜色
        width=0.8,                  # 边的宽度
        style='solid',              # 边的样式
        ax=None,                    # Matplotlib Axes对象，可选在指定的Matplotlib轴中绘制图形。
        )

plt.show()

# %%
g = nx.DiGraph([(1,2,{'weight':10}), (2,3),(3,4),(1,4),(4,2)], name= 'my digraph')

g.graph['b'] = 19

g.add_node('b', time = 0.2)

g.add_edge('a', 'b', weight = 0.6)

g.add_edges_from( [ (2,3),(3,4) ], color="red")

g.add_edges_from( [(1,2,{"color":"blue"}),(4,5,{"weight":8})])

nx.add_path(g, [0, 4,3])

nx.draw(g,pos = nx.circular_layout(g),with_labels=True)
 
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import json

import networkx as nx

import matplotlib.pyplot as plt

def process(f_list):

    f = open('日志文档/action05.txt', encoding= 'UTF-8')

    text1 = f.read().replace('\\', '')

    splitList = text1.strip().split('\n')[1:]

    IPDictionary = {}

    for i in range(len(splitList)):

        f = open('日志文档/action05r.txt', 'a')

        writeFile =  splitList[i]

        matchText = re.search(r'^"\d+" ', writeFile)

        if matchText:

            xx = writeFile.replace(matchText.group(),"").strip('"')+'\n'
        
        
        f.write(xx)  
        dic = json.loads(xx)

        targetIP = dic['_source']['targetObject']['ip']

        sourceIP = dic['_source']['sourceObject']['ip']

        if sourceIP not in IPDictionary.keys():

            IPDictionary[sourceIP]=[targetIP]

        else:

            IPDictionary[sourceIP].append(targetIP)

    

    f.close()

       
G = nx.DiGraph()

edges_list = []

for key in IPDictionary.keys():

    for value in IPDictionary[key]:

        edges_list.append((key, value))

G.add_edges_from(edges_list)
        
nx.draw(G, with_labels= True, pos = nx.spring_layout(G))                          #绘制网络G

#plt.savefig("ba.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-9f401f3ef908> in <module>()
#      52 edges_list = []
#      53
# ---> 54 for key in IPDictionary.keys():
#      55
#      56     for value in IPDictionary[key]:
#
# NameError: name 'IPDictionary' is not defined

# %%
import os

import json

import re

import networkx as nx

import matplotlib.pyplot as plt

fp = 'C:\\Users\\Tommy\\Desktop\\日志文档'

fpw = 'C:\\Users\\Tommy\\Desktop\\a'

os.chdir(fp)

    

def eachfile(filepath):
    workfile=[]
    pathdir=os.listdir(filepath)

    for s in pathdir:
        newdir = os.path.join(filepath,s) # 将文件命加入到当前文件路径后面
        if os.path.isfile(newdir):        #如果是文件
            workfile.append(newdir)

    return workfile 

def write_flist(fp ,fpw):
    
    f = eachfile(fp)
    
    write_list = []
    for i in range(len(f)):
        file = open('C:\\Users\Tommy\\Desktop\\a\\'+f[i].split('\\')[-1] ,'w')

    
    pathdir=os.listdir(fpw)

    for s in pathdir:
        newdir = os.path.join(fpw,s) # 将文件命加入到当前文件路径后面
        if os.path.isfile(newdir):        #如果是文件
            write_list.append(newdir)
    
    return write_list

def process(f_list, i, write_list):
    
    f = open(f_list[i], encoding= 'UTF-8')

    text1 = f.read().replace('\\', '')

    splitList = text1.strip().split('\n')[1:]

    IPDictionary = {}

    for j in range(len(splitList)):

        fr = open(write_list[i], 'a')

        writeFile =  splitList[j]

        matchText = re.search(r'^"\d+" ', writeFile)

        if matchText:

            xx = writeFile.replace(matchText.group(),"").strip('"')+'\n'
        
        
        fr.write(xx)  
        dic = json.loads(xx)
        if ('ip' in dic['_source']['targetObject'].keys() and dic['_source']['sourceObject'].keys()):
        
            targetIP = dic['_source']['targetObject']['ip']

            sourceIP = dic['_source']['sourceObject']['ip']

        else:
            
            continue
            
        if sourceIP not in IPDictionary.keys():

            IPDictionary[sourceIP]=[targetIP]

        else:

            IPDictionary[sourceIP].append(targetIP)

    
    f.close()
    
    return IPDictionary
    
    
def process_files(fp,fpw):
    
    f = eachfile(fp)
    
    w = write_flist(fp, fpw)
    
    all_Ipdict = {}
    
    for i in range(len(f)):
        
        all_Ipdict[f[i].split('\\')[-1]] = process(f, i, w)
    
    return all_Ipdict

if __name__ == '__main__':
    
    all_dict = process_files(fp, fpw)
    
    G = nx.DiGraph()

    edges_list = []
    
    for key1 in all_dict.keys():

        for key in all_dict[key1].keys():

            for value in all_dict[key1][key]:

                edges_list.append((key, value))

        G.add_edges_from(edges_list)
        
    nx.draw(G, with_labels= True, pos = nx.spring_layout(G))                          #绘制网络G

    #plt.savefig("ba.png")
    plt.show()

# %%
f= eachfile(fp)

f[1].split('\\')[-1][:-4]
# Out:
# 'action06'
